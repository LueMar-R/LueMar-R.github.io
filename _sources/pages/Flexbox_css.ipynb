# %% [markdown]
# LES FLEXBOX AVEC CSS

# %% [markdown]
# Le CSS (Cascading Style Sheet) est un langage informatique servant à décrire la présentation et le style d’un document HTML et XML. Datant des années 90, ce langage sert principalement au développement de sites web.
# Il permet d'appliquer differents styles sur les éléments sélectionnés.

# %% [markdown]
# On a le choix car on peut écrire du code en langage CSS à trois endroits différents :
#
#     dans un fichier .css  (méthode la plus recommandée) ;
#
#     dans l'en-tête <head>  du fichier HTML ;
#
#     directement dans les balises du fichier HTML via un attribut style  (méthode la moins recommandée).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <img src = "box.png">

# %% [raw]
# html{
#     background-color:white;
# }
#
# body{
#     width:600px;
#     margin:0 auto;
#     background_color:#ff9500;
#     padding:020px 20px 20px;
#     border: 5px solid black;}
# }

# %% [markdown]
# Un conteneur, des éléments
#
# Le principe de la mise en page avec Flexbox est simple : vous définissez un conteneur, et à l'intérieur vous placez plusieurs éléments. Imaginez un carton dans lequel vous rangez plusieurs objets : c'est le principe !
#
# Sur une même page web, vous pouvez sans problème avoir plusieurs conteneurs (plusieurs cartons, si vous préférez ;) ). Ce sera à vous d'en créer autant que nécessaire pour obtenir la mise en page que vous voulez.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Le conteneur est une balise HTML, et les éléments sont d'autres balises HTML à l'intérieur

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  Si je mets une (une seule !) propriété CSS, tout change. Cette propriété, c'est flex  , et je l'applique au conteneur :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Grâce à ce code les blocs se collent les uns aux autres.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Flexbox permet d'agencer les blocs dans le sens voulu

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# row : organisés sur une ligne (par défaut) ;
#
# column : organisés sur une colonne ;
#
# row-reverse : organisés sur une ligne, mais en ordre inversé ;
#
# column-reverse : organisés sur une colonne, mais en ordre inversé

# %% [markdown]
# # Police d'ecriture.

# %% [markdown]
# Une taille absolue
#
# Pour indiquer une taille absolue, on utilise généralement les pixels. Pour avoir un texte de 16 pixels de hauteur, vous devez donc écrire

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Il y a plusieurs moyens d'indiquer une valeur relative. Vous pouvez par exemple écrire la taille avec des mots en anglais comme ceux-ci :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://openclassrooms.com/fr/courses/1603881-apprenez-a-creer-votre-site-web-avec-html5-et-css3/1605329-formatez-du-texte
